# %%
import pandas as pd

full_data = pd.read_csv("/Users/huafa/Downloads/full_data.csv")
crypto_tweets = pd.read_csv("/Users/huafa/Downloads/crypto_tweets.csv")

# %%
full_data_filtered = full_data.merge(crypto_tweets, on = 'date', how='left').dropna(subset=['tweet'])
full_data_filtered = full_data_filtered.drop(columns=['Unnamed: 0'])
full_data_filtered
# Out:
#            date      btc_open     btc_close    btc_volume  nasdaq_close  \
# 2    2021-02-04  37475.105469  36926.066406   68838074392  13777.740234
# 4    2021-02-08  38886.828125  46196.464844  101467222687  13987.639648
# 6    2021-02-10  46469.761719  44918.183594   87301089896  13972.530273
# 7    2021-02-11  44898.710938  47909.332031   81388911810  14025.769531
# 8    2021-02-12  47877.035156  47504.851563   76555041196  14095.469727
# ..          ...           ...           ...           ...           ...
# 229  2022-01-20  41744.027344  40680.417969   20382033940  14154.019531
# 230  2022-01-21  40699.605469  36457.316406   43011992031  13768.919922
# 231  2022-01-25  36654.804688  36954.003906   26428189594  13539.290039
# 232  2022-01-26  36950.515625  36852.121094   31324598034  13542.120117
# 233  2022-01-27  36841.878906  37138.234375   25041426629  13352.780273
#
#         dji_close     sp_close  oil_close   gold_close  compound  positive  \
# ...

# %%
full_data_filtered.to_csv('/Users/huafa/Downloads/full_data_filtered.csv', index=False)
